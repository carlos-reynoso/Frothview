# %%
# Importacion de librerias
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
img=cv2.imread('data/134.jpg') # Lectura de la imagen

# %%
plt.imshow(img) # Muestra de la imagen

# %%
img2=img[480:830,600:1000,1] # Recorte de la imagen
plt.imshow(img2)         # Muestra de la imagen recortada

# %%
pix=img2.shape[0] # Tamaño de la imagen recortada
pix
# Out:
# 350

# %%
cm=2 # Tamaño de la referencia en cm

# %%
f=cm/pix # Factor de conversion
f
# Out:
# 0.005714285714285714
